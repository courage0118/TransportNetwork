# %%
class YourClassName:
    def __init__(self):
        self.Nodes = []  # 网络包含节点集合
    
    def create_nodes(self):
        for node_id in range(1, 13):
            new_node = node()
            new_node.ID = node_id
            self.Nodes.append(new_node)

# %%
def read_nodes(self):
    # 直接设置节点信息为1-12共12个节点
    for i in range(1, 13):
        newnode = node()
        newnode.ID = i
        self.Nodes.append(newnode)

def read_link(self, path):
    f = open(path)
    file = f.readlines()
    linkid = 1
    for i in file:
        row = i.strip('\n').split(',')
        newlink = link()
        newlink.ID = linkid
        newlink.O_link = self.Nodes[int(row[0])]
        newlink.D_link = self.Nodes[int(row[1])]
        newlink.FFT = float(row[2])
        newlink.Capacity = float(row[3])
        newlink.O_link.outnode.append(newlink.ID)
        newlink.D_link.innode.append(newlink.ID)
        linkid += 1
        self.Links.append(newlink)
    f.close()

def read_od(self, path):
    f = open(path)
    file = f.readlines()
    for i, line in enumerate(file):
        row = line.strip('\n').split(',')
        for j, demand in enumerate(row):
            if i > 0 and j > 0:
                neworigin = OD()
                self.num_Origins += 1
                neworigin.ID = self.num_Origins
                neworigin.origin_node = self.Nodes[i]
                self.Nodes[i].origin = neworigin.ID
                self.Origins.append(neworigin)
                self.Origins[neworigin.ID - 1].Destination.append(self.Nodes[j])
                self.Origins[neworigin.ID - 1].odlinks_demand.append(float(demand))
    f.close()

# %%
    def read_link(self, path):
        f = open(path)
        file = f.readlines()
        linkid = 1
        for i in file:
            row = i.strip('\n').split(',')
            newlink = link()
            newlink.ID = linkid
            newlink.O_link = self.Nodes[int(row[0])]
            newlink.D_link = self.Nodes[int(row[1])]
            newlink.FFT = float(row[2])
            newlink.Capacity = float(row[3])
            newlink.O_link.outnode.append(newlink.ID)
            newlink.D_link.innode.append(newlink.ID)
            linkid += 1
            self.Links.append(newlink)
        f.close()

    def read_od(self, path):
        f = open(path)
        file = f.readlines()
        for i, line in enumerate(file):
            row = line.strip('\n').split(',')
            for j, demand in enumerate(row):
                if i > 0 and j > 0:
                    neworigin = OD()
                    self.num_Origins += 1
                    neworigin.ID = self.num_Origins
                    neworigin.origin_node = self.Nodes[i]
                    self.Nodes[i].origin = neworigin.ID
                    self.Origins.append(neworigin)
                    self.Origins[neworigin.ID - 1].Destination.append(self.Nodes[j])
                    self.Origins[neworigin.ID - 1].odlinks_demand.append(float(demand))
        f.close()

# %%
    def read_nodes(self,path):#读取节点信息
        f=open(path)
        file=f.readlines()
        for i in file:
            row=i.strip('\n').split('\t')
            newnode=node()
            newnode.ID=int(row[0])
            self.Nodes.append(newnode)
        f.close()
    def read_link(self,path):#读取路段信息
        f=open(path)
        file=f.readlines() 
        linkid=1
        for i in file:
            row=i.strip('\n').split('\t')
            newlink=link()
            newlink.ID=linkid
            newlink.O_link=self.Nodes[int(row[0])-1]
            newlink.D_link=self.Nodes[int(row[1])-1]
            newlink.FFT=float(row[2])
            newlink.Capacity=float(row[3])
            newlink.O_link.outnode.append(newlink.ID)
            newlink.D_link.innode.append(newlink.ID)
            #self.Nodes[int(row[0])-1].innode.append(newlink.ID)
            linkid+=1
            self.Links.append(newlink) 
        f.close()
